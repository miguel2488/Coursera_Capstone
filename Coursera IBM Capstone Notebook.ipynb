# %% [markdown]
# # IBM & COURSERA DATA SCIENCE CAPSTONE PROJECT
# #### The goal of this notebook is to be used as the main developing environment for the Data Science Capstone Project for the IBM Data Science Track in Coursera

# %%
import pandas as pd
import numpy as np
# Out:
# Waiting for a Spark session to start...
# Spark Initialization Done! ApplicationId = app-20180920084837-0000

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
